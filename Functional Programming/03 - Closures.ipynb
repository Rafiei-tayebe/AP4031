# %% [markdown]
# #### Example 1:
# Let’s say we want to implement a counter to record how many time the word has been repeated. The first thing you may want to do is to define a dictionary in global scope, and then create a function to add in the words as key into this dictionary and also update the number of times it repeated. Below is the sample code:

# %%
counter = dict()

def count_word(word):  
    global counter  
    
    # some validation ...
    word = word.lower()
    if word not in ['the', 'or', 'and', 'is', 'am', 'are'] and not word.isdigit():
        counter[word] = counter.get(word, 0) + 1
        return counter[word]
    
    return 0

text = 'Java Python Java Java Python C# 1234 the'
for word in text.split():
    print(counter)
    print(count_word(word))
# Out:
# {}
# 1
# {'java': 1}
# 1
# {'java': 1, 'python': 1}
# 2
# {'java': 2, 'python': 1}
# 3
# {'java': 3, 'python': 1}
# 2
# {'java': 3, 'python': 2}
# 1
# {'java': 3, 'python': 2, 'c#': 1}
# 0
# {'java': 3, 'python': 2, 'c#': 1}
# 0

# %%
counter = {'java': 3, 'python': 3, 'c#': 1}

# %%
counter.get('j', 10) # counter['java']
# Out:
# 10

# %%
counter
# Out:
# {'java': 3, 'python': 3, 'c#': 1}

# %%
count_word('python')
# Out:
# 3

# %%
counter[1234] = 1

# %%
counter
# Out:
# {'java': 3, 'python': 3, 'c#': 1, 1234: 1}

# %%
counter

# To make sure the count_word function updates the correct “counter”,
# we need to put the global keyword to explicitly tell Python interpreter
# to use the “counter” defined in global scope, not any variable we accidentally
# defined with the same name in the local scope (within this function).

# %% [markdown]
# #### issue1 :
# The global variable is accessible to any of the other functions and you cannot guarantee your data won’t be modified by others.
#
# #### issue2 :
# The global variable exists in the memory as long as the program is still running, so you may not want to create so many global variables if not necessary.

# %%
#### Solution: bound the variable with the function inside another function

def word_counter():
    counter = dict()
    
    def count(word):
        nonlocal counter
        word = word.lower()
        if word not in ['the', 'or', 'and', 'is', 'am', 'are'] and not word.isdigit():
            counter[word] = counter.get(word, 0) + 1
            return counter[word]
        else:
            return 0
        
    return count

# %%
count1 = word_counter()

# %%
type(count1)
# Out:
# function

# %%
text = 'Java Python Java Java Python C# 1234 the'
for word in text.split():
    print(count1(word))
# Out:
# 1
# 1
# 2
# 3
# 2
# 1
# 0
# 0

# %%
count1('java')
# Out:
# 4

# %% [markdown]
# the counter dictionary is hidden from the public access and the functionality remains the same.

# %%
count1 = word_counter() # counter = dict() , count
count2 = word_counter() # counter = dict() , count
#count
text = 'Java Python Java Java Python C# 1234 the'
for word in text.split():
    print(count1(word))

print('-------------')
text = 'Java Java Java C# 1234 the'
for word in text.split():
    print(count2(word))
# Out:
# 1
# 1
# 2
# 3
# 2
# 1
# 0
# 0
# -------------
# 1
# 2
# 3
# 1
# 0
# 0

# %%
d('python')
# Out:
# 1

# %% [markdown]
# Dont worry! It is a closure
#
# -------

# %% [markdown]
# ### Closures

# %% [markdown]
# Functions defined inside another function can access the outer (nonlocal) variables

# %%
def outer():
    x = 'python' # non-local variable x (or free variable)
    def inner(): # a function defined inside the outer function 
        print(f'{x} rocks') # and referenced x, which is defined in the outer function
    return inner

# %% [markdown]
# when we consider inner, we really are looking at two things:
# + the function inner
# + the free variable x (with current value python)
#   x is not in the local scope of inner, it is in somewhere else
#
# This two things have to __bound together__ . It is called a closure.
# closure is a nested function remembers and has access to variables in the scope of the function in which it is defined.
#
# A Closure is a __function__ plus an extended scope that contains the __free variables__

# %%
def outer():
    x = 'python' # non-local variable x (or free variable)
    def inner(): # a function defined inside the outer function 
        print(f'{x} rocks') # and referenced x, which is defined in the outer function
    return inner

# %%
fn = outer() # fn is (inner + free variable). it creates inner (no run)

# %%
type(fn)
# Out:
# function

# %%
fn()
# Out:
# python rocks

# %%
fn() #
# Out:
# python rocks

# %%
type(fn)
# Out:
# function

# %%
fn.__code__.co_freevars
# Out:
# ('x',)

# %% [markdown]
# As we can see, `x` is a free variable in the closure.

# %% [markdown]
# #### Why do we use closures?
# 1. Hide data with Python closure <br>
#    Example 1
# 2. Convert small class to function with Python closure <br>
#    Example 2
# 3. Decorators <br>
#    Next part

# %% [markdown]
# #### Example 2
# Occasionally in your project, you may want to implement a small utility class to do some simple task. Let’s take a look at the below example:

# %%
import requests

# %%
page = requests.get('https://divar.ir/s/tehran/car?price=100000000-200000000')

# %%
page.text
# Out:
# '<!doctype html>\n<html lang="fa-IR" dir="rtl">\n<head>\n  \n  \n  <meta charset="utf-8">\n  <meta http-equiv="X-UA-Compatible" content="IE=edge">\n  <meta http-equiv="Content-Type" content="text/html; charset=UTF-8">\n  <meta name="format-detection" content="telephone=no" />\n  <link rel="preconnect" href="https://s100.divarcdn.com" />\n  <link rel="dns-prefetch" href="https://s100.divarcdn.com">\n    <link href=https://s100.divarcdn.com/statics/2023/10/IRANSansWeb.cdb118d6.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link href=https://s100.divarcdn.com/statics/2023/10/IRANSansWeb_Medium.9f338149.woff2 type=font/woff2 as=font rel=preload crossorigin=anonymous>\n    <link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/runtime.499753c6.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/framework.d8ffbc66.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/khesht.0e066054.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/polyfills.226652e3.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/vendors.00b4b58a.desktop.js">\n<link data-chunk="main" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/main.a80a748c.desktop.js">\n<link data-chunk="bootstrap" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/components-160.d9c22852.desktop.js">\n<link data-chunk="bootstrap" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/utils-1493.c0097d09.desktop.js">\n<link data-chunk="bootstrap" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/store-4119.ae943aa7.desktop.js">\n<link data-chunk="bootstrap" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/services-9894.66026b3f.desktop.js">\n<link data-chunk="bootstrap" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/localization-6607.7c568abc.desktop.js">\n<link data-chunk="bootstrap" rel="modulepreload" as="script" href="https://s100.divarcdn.com/statics/2023/10/bootstrap-5672.dae56a42.desktop.js">\n    \n  <link rel="manifest" href="/manifest.json" crossorigin="use-credentials">\n  <link rel="search" type="application/opensearchdescription+xml" title="Divar" href="/opensearch.xml" />\n  <link rel="apple-touch-icon" sizes="180x180" href="https://s100.divarcdn.com/static/thewall-assets/apple-touch-icon.png">\n  <link rel="icon" type="image/png" sizes="32x32" href="https://s100.divarcdn.com/static/thewall-assets/favicon-32x32.png">\n  <link rel="icon" type="image/png" sizes="16x16" href="https://s100.divarcdn.com/static/thewall-assets/favicon-16x16.png">\n  <link rel="mask-icon" href="https://s100.divarcdn.com/static/thewall-assets/safari-pinned-tab.svg" color="#a62626">\n  <meta name="theme-color" content="#ffffff">\n  <link rel="publisher" href="https://plus.google.com/+DivarIr">\n  \n  <script type="text/javascript">performance && performance.mark(\'loadStylingStart\');</script>\n    <link data-chunk="main" rel="stylesheet" href="https://s100.divarcdn.com/statics/2023/10/vendors-1216.4c7a1ad7.desktop.css">\n<link data-chunk="main" rel="stylesheet" href="https://s100.divarcdn.com/statics/2023/10/main-179.fdd70b39.desktop.css">\n<link data-chunk="bootstrap" rel="stylesheet" href="https://s100.divarcdn.com/statics/2023/10/components-160.95c5486a.desktop.css">\n<link data-chunk="bootstrap" rel="stylesheet" href="https://s100.divarcdn.com/statics/2023/10/bootstrap-5672.fac91a72.desktop.css">\n  <script type="text/javascript">\n    performance && performance.mark(\'loadStylingEnd\');\n    performance && performance.measure(\'loadStyling\', \'loadStylingStart\', \'loadStylingEnd\');\n  < ...

# %%
url = 'https://divar.ir/s/{city}/{item}?price={min_price}-{max_price}'.format(
    city = 'tehran', item = 'car', min_price = 100000000, max_price = 200000000)

# %%
city = 'tehran'
item = 'car'
min_price = 100000000
max_price = 200000000
url = f'https://divar.ir/s/{city}/{item}?price={min_price}-{max_price}'

# %%
print(url)
# Out:
# https://divar.ir/s/tehran/car?price=100000000-200000000

# %%
import requests

class RequestMaker:
    def __init__(self, base_url):
        self.url = base_url
        
    def request(self, **kwargs):
        return requests.get(self.url.format_map(kwargs))

# %%
divar = RequestMaker('https://divar.ir/s/{city}/{item}?price={min_price}-{max_price}')
divar.request(city = 'tehran', item = 'car', min_price = 100000000, max_price = 200000000)
# Out:
# <Response [200]>

# %%
divar.request(city = 'new york', item = 'car', min_price = 100000000, max_price = 200000000)
# Out:
# <Response [404]>

# %% [markdown]
# Since you’ve already seen in the word counter example, the closure can also hold the data for your later use, the above class can be converted into a function with closure:

# %%
import requests

def request_maker(url):
    def make_request(**kwargs):
        return requests.get(url.format_map(kwargs))
    return make_request

# %% [markdown]
# The code becomes more concise and achieves the same result. Take note that in the above code, we are able to pass in the arguments into the nested function with \*\*kwargs (or \*args).

# %%
divar = request_maker('https://divar.ir/s/{city}/{item}?price={min_price}-{max_price}')
divar(city = 'tehran', item = 'car', min_price = 100000000, max_price = 200000000)
# Out:
# <Response [200]>

# %% [markdown]
# ### Multiple Instances of Closures

# %%
def pow(n):
    # n is local to pow
    
    def inner(x):
        # x is local to inner
        return x ** n
    return inner

# %%
p2 = pow(2) # n =2 , inner
print(p2(10))

p3 = pow(3)
print(p3(3), p3(2))

# %% [markdown]
# In this example, `n`, in the function `inner` is a free variable, so we have a closure that contains `inner` and the free variable `n`

# %%
square = pow(2) # n= 2

# %%
square(6)
# Out:
# 36

# %%
cube = pow(3) # n= 3

# %%
cube(5)
# Out:
# 125
